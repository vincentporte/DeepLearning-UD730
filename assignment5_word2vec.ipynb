# %%
#Deep Learning - Assignment 5
#The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data

# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
#Download the data from the source website if necessary.

url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
#Read the data into a string.

def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
#Build the dictionary and replace rare words with UNK token

vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
    #print (word, dictionary[word])
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
#Function to generate a training batch for the skip-gram model.

data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  """
  
  Parameters
  ----------
  num_skips: int : How many times to reuse an input to generate a label.
  skips_window: int : How many words to consider left and right.
  
  """
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

#for num_skips, skip_window in [(2, 1), (4, 2)]:
for num_skips, skip_window in [(2, 1), (4, 2), (8, 4)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'originated', 'term', 'as', 'of']
#
# with num_skips = 8 and skip_window = 4:
#     batch: ['term', 'term', 'term', 'term', 'term', 'term', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'first', 'abuse', 'used', 'originated', 'of']

# %%
print('data: {}'.format(' '.join([reverse_dictionary[di] for di in data[:200]])))
# Out:
# data: anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans UNK of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or UNK but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic institutions anarchists advocate social relations based upon voluntary association of autonomous individuals mutual aid and self governance while anarchism is most easily defined by what it is against anarchists also offer positive visions of what they believe to be a truly free society

# %%
#Train a skip-gram model.

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

#with graph.as_default(), tf.device('/gpu:0'):
with graph.as_default():

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.058359
# Nearest to not: judgements, marquess, cultivars, backside, baby, geologically, scientific, gateless,
# Nearest to to: northernmost, mno, acclamation, betty, millet, apostate, unplugged, helaman,
# Nearest to will: gangster, haunted, refuge, goguryeo, hindemith, mixes, distaste, anthroposophy,
# Nearest to this: adultery, taxa, allende, tailpiece, lawyer, unam, identifiable, bristol,
# Nearest to have: oppressive, papier, koko, offences, daleks, memnon, namespaces, requires,
# Nearest to s: fuze, gallienus, db, kiosk, religiously, maronites, returning, alloys,
# Nearest to and: ordination, uomo, greifswald, academies, traveller, homecoming, scalability, transmutation,
# Nearest to at: nowadays, gustavus, respectfully, dominatrices, roald, cake, parrish, dodd,
# Nearest to can: armando, locals, spiritualism, wuxia, videogames, opportunistic, illustrations, fear,
# Nearest to UNK: tarentum, brazilians, molecule, khanum, ki, barreled, abdominal, butyl,
# Nearest to in: lulu, vogue, frustrations, undertakings, kilkenny, tenn, dodgers, sync,
# Nearest to such: constituted, dioxin, digestion, fawcett, khanna, lizard, brahmic, bizkit,
# Nearest to as: replicates, pickens, volcanism, pilgrims, structured, slain, sopranos, dct,
# Nearest to often: zog, pf, pathological, parallax, buccaneers, unwelcome, leninist, sopranos,
# Nearest to there: holdings, graz, groin, doll, eleventh, ghali, scraping, sis,
# Nearest to all: thales, relena, fantasies, tells, opposites, auden, misnomer, liszt,
# Average loss at step 2000: 4.367163
# Average loss at step 4000: 3.858274
# Average loss at step 6000: 3.793532
# Average loss at step 8000: 3.691042
# Average loss at step 10000: 3.615576
# Nearest to not: it, they, still, he, overstated, often, pelican, ductus,
# Nearest to to: would, will, frye, wallet, you, emergency, reunion, acclamation,
# Nearest to will: edition, would, to, actors, may, anthroposophy, refuge, hindemith,
# Nearest to this: it, the, which, that, a, another, lawyer, too,
# Nearest to have: has, had, be, are, were, imf, covenants, oppressive,
# Nearest to s: his, stylistic, immobile, hydrology, or, pox, prosper, gonna,
# Nearest to and: or, harum, rightly, bollywood, internationalization, renamed, but, splendour,
# Nearest to at: in, fundamentalist, gustavus, on, nowadays, by, hopper, stream,
# Nearest to can: may, would, videogames, hartman, could, survive, reminiscent, discontinue,
# Nearest to UNK: strata, toward, adr, principal, wenders, humanities, october, authors,
# Nearest to in: of, on, at, from, dominic, for, sweeping, with,
# Nearest to such: patrimony, macmillan, constituted, dioxin, diocletian, cira, wold, omit,
# Nearest to as: by, after, dago, few, ancillary, handler, drowned, with,
# Nearest to often: pf, not, buccaneers, zog, ascribes, bridgeport, they, it,
# Nearest to there: it, he, they, oklahoma, no, eleventh, which, cannot,
# Nearest to all: cascading, nestorius, some, relena, quarrels, misnomer, speleological, wy,
# Average loss at step 12000: 3.607127
# Average loss at step 14000: 3.570135
# Average loss at step 16000: 3.412158
# Average loss at step 18000: 3.458033
# Average loss at step 20000: 3.541220
# Nearest to not: ductus, still, less, it, geologically, never, also, to,
# Nearest to to: would, will, not, can, congruence, reunion, wallet, acclamation,
# Nearest to will: would, may, can, should, could, frye, to, must,
# Nearest to this: it, which, the, another, a, that, permissible, what,
# Nearest to have: had, has, were, be, are, emancipated, covenants, ataxia,
# Nearest to s: stylistic, groupoids, seasoned, inclusions, fuze, protium, subtracting, rasputin,
# Nearest to and: or, but, suk, in, which, sudden, bollywood, primigenius,
# Nearest to at: in, on, during, fundamentalist, above, from, bauds, shenzhen,
# Nearest to can: may, would, could, should, will, must, might, cannot,
# Nearest to UNK: salerno, discount, strata, principal, propto, succeeds, dlp, psychology,
# Nearest to in: at, on, during, with, for, from, and, by,
# Nearest to such: well, patrimony, macmillan, wold, commons, constituted, omit, distinct,
# Nearest to as: prohibited, firewall, ancillary, conservatism, nolo, bains, gauze, congregational,
# Nearest to often: pf, generally, also, commonly, usually, buccaneers, altair, ascribes,
# Nearest to there: it, they, he, which, no, who, usually, but,
# Nearest to all: some, several, those, many, every, nestorius, both, women,
# Average loss at step 22000: 3.503856
# Average loss at step 24000: 3.486643
# Average loss at step 26000: 3.479280
# Average loss at step 28000: 3.482669
# Average loss at step 30000: 3.502249
# Nearest to not: still, it, they, only, never, you, gonads, less,
# Nearest to to: will, would, can, could, should, must, may, mno,
# Nearest to will: would, can, may, could, must, should, to, cannot,
# Nearest to this: which, it, that, another, what, there, allende, gv,
# Nearest to have: had, has, are, were, be, emancipated, ataxia, produce,
# Nearest to s: his, gonna, immobile, tributary, specialised, turbo, hiss, and,
# Nearest to and: or, but, in, from, which, ethnography, cerebrum, dinara,
# Nearest to at: in, during, on, fundamentalist, before, above, infected, synoptic,
# Nearest to can: may, would, will, could, should, must, cannot, might,
# Nearest to UNK: strata, garde, principal, proton, nominating, condense, purana, financed,
# Nearest to in: of, at, on, during, from, and, dominic, competences,
# Nearest to such: well, commons, known, macmillan, aswan, these, other, patrimony,
# Nearest to as: by, conservatism, cowboy, smack, ancillary, nolo, firewall, rds,
# Nearest to often: generally, commonly, also, usually, sometimes, pf, who, ascribes,
# Nearest to there: they, it, he, still, usually, which, who, dribble,
# Nearest to all: some, these, several, many, every, those, specimens, microchip,
# Average loss at step 32000: 3.502906
# Average loss at step 34000: 3.493570
# Average loss at step 36000: 3.452720
# Average loss at step 38000: 3.305881
# Average loss at step 40000: 3.429329
# Nearest to not: still, never, they, often, it, ductus, only, now,
# Nearest to to: will, should, could, can, must, would, and, may,
# Nearest to will: would, can, may, could, must, should, cannot, to,
# Nearest to this: which, it, another, the, that, what, technologically, there,
# Nearest to have: had, has, were, are, be, tyrannical, already, emancipated,
# Nearest to s: his, schriften, omnibus, glycolysis, melbourne, koalas, mixolydian, hypoxic,
# Nearest to and: or, but, in, forested, with, crag, on, to,
# Nearest to at: during, on, motionless, nowadays, between, before, zoran, discrediting,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to UNK: allegorical, immemorial, b, h, ra, travelers, wenders, rightly,
# Nearest to in: and, of, within, for, via, from, during, dominic,
# Nearest to such: well, known, these, commons, macmillan, many, aswan, wold,
# Nearest to as: smack, rds, constitutes, kuleshov, untersuchungen, ancillary, castle, opus,
# Nearest to often: usually, generally, commonly, sometimes, also, widely, pf, who,
# Nearest to there: they, it, he, which, still, usually, now, but,
# Nearest to all: every, these, both, backronym, several, zs, specimens, endl,
# Average loss at step 42000: 3.437877
# Average loss at step 44000: 3.447782
# Average loss at step 46000: 3.449476
# Average loss at step 48000: 3.357321
# Average loss at step 50000: 3.381762
# Nearest to not: still, never, ductus, gonads, considered, now, who, they,
# Nearest to to: must, would, congruence, should, mno, pilsner, morehouse, from,
# Nearest to will: would, could, can, may, must, should, cannot, might,
# Nearest to this: which, it, the, some, that, what, he, another,
# Nearest to have: had, has, were, be, are, tyrannical, previously, already,
# Nearest to s: koalas, groupoids, seasoned, hypoxic, although, and, customized, tributary,
# Nearest to and: or, but, while, of, including, in, spacetime, yet,
# Nearest to at: during, discrediting, in, between, motionless, on, malmesbury, claudia,
# Nearest to can: may, would, could, must, will, should, might, cannot,
# Nearest to UNK: axiom, h, dredging, caliphs, de, la, upto, rapidity,
# Nearest to in: during, of, on, dominic, throughout, from, since, under,
# Nearest to such: well, these, known, many, commons, wold, regarded, doodle,
# Nearest to as: kuleshov, became, millisecond, dago, gainesville, ancillary, ugle, invader,
# Nearest to often: usually, generally, commonly, sometimes, also, widely, now, frequently,
# Nearest to there: they, it, he, she, but, still, now, predicts,
# Nearest to all: both, specimens, each, these, every, immense, backronym, some,
# Average loss at step 52000: 3.435090
# Average loss at step 54000: 3.430507
# Average loss at step 56000: 3.440233
# Average loss at step 58000: 3.401645
# Average loss at step 60000: 3.392716
# Nearest to not: never, still, now, ductus, gonads, you, normally, almost,
# Nearest to to: would, joual, must, inheritors, will, may, mno, acclamation,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to this: it, which, that, the, what, there, some, weiner,
# Nearest to have: had, has, were, are, produce, require, be, having,
# Nearest to s: tributary, melbourne, groupoids, higham, although, synagogue, isbn, robbery,
# Nearest to and: or, but, including, sorrows, however, antics, reactive, reconstructionism,
# Nearest to at: during, discrediting, whenever, in, near, nisibis, within, without,
# Nearest to can: may, would, could, will, should, must, cannot, might,
# Nearest to UNK: wenders, audiovisual, nominating, usb, preseason, pow, leaf, publicist,
# Nearest to in: within, during, throughout, of, among, under, alike, from,
# Nearest to such: well, these, known, many, commons, wold, minority, aswan,
# Nearest to as: ancillary, gainesville, oecd, firewall, invader, millisecond, opus, peng,
# Nearest to often: usually, sometimes, commonly, generally, now, also, frequently, widely,
# Nearest to there: they, it, he, now, still, this, she, which,
# Nearest to all: both, every, those, these, each, some, any, specimens,
# Average loss at step 62000: 3.237897
# Average loss at step 64000: 3.264803
# Average loss at step 66000: 3.404098
# Average loss at step 68000: 3.397360
# Average loss at step 70000: 3.363147
# Nearest to not: never, still, now, equally, usually, generally, almost, gonads,
# Nearest to to: will, can, would, must, may, mno, should, callisthenes,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to this: which, it, the, that, some, what, another, there,
# Nearest to have: had, has, were, are, require, be, having, produce,
# Nearest to s: whose, grupo, isbn, pooh, the, gst, specialised, koalas,
# Nearest to and: or, but, which, shorthair, like, including, while, of,
# Nearest to at: during, without, within, in, whenever, on, after, near,
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Nearest to UNK: poses, anna, bartleby, detrimental, bosses, bothered, bhp, blindness,
# Nearest to in: within, during, on, for, throughout, alike, until, among,
# Nearest to such: these, well, known, many, grumman, minority, commons, wold,
# Nearest to as: nolo, humiliation, millisecond, because, using, kuleshov, when, is,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, widely, also,
# Nearest to there: they, it, he, still, we, now, she, usually,
# Nearest to all: every, many, some, both, any, these, each, several,
# Average loss at step 72000: 3.375524
# Average loss at step 74000: 3.352429
# Average loss at step 76000: 3.313825
# Average loss at step 78000: 3.353587
# Average loss at step 80000: 3.377091
# Nearest to not: still, never, actually, equally, usually, now, normally, often,
# Nearest to to: mno, would, pilsner, joual, will, virginal, should, inkjet,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to this: which, it, the, what, zwingli, another, apo, there,
# Nearest to have: had, has, are, be, were, require, having, produce,
# Nearest to s: isbn, marksmanship, seasoned, ishmael, tributary, gabaa, microstates, bogus,
# Nearest to and: or, but, while, including, frontispiece, than, kwashiorkor, tricking,
# Nearest to at: during, in, on, jo, seashore, without, impeded, whenever,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to UNK: fujian, smith, abramovich, turner, propto, richard, appellation, mit,
# Nearest to in: during, within, on, until, throughout, at, dominic, of,
# Nearest to such: well, these, known, classified, commons, follows, regarded, many,
# Nearest to as: papen, ugle, filmmaking, constitutes, untersuchungen, millisecond, rodrigues, liturgics,
# Nearest to often: sometimes, usually, generally, commonly, frequently, widely, now, still,
# Nearest to there: they, it, he, we, still, she, now, usually,
# Nearest to all: both, every, any, each, many, several, specimens, various,
# Average loss at step 82000: 3.410415
# Average loss at step 84000: 3.411328
# Average loss at step 86000: 3.393028
# Average loss at step 88000: 3.355141
# Average loss at step 90000: 3.366680
# Nearest to not: still, never, actually, equally, nor, now, quite, also,
# Nearest to to: mno, pilsner, must, inheritors, paws, should, will, congruence,
# Nearest to will: would, can, could, must, should, may, might, cannot,
# Nearest to this: it, which, the, another, some, zwingli, kazakhstani, he,
# Nearest to have: had, has, are, were, require, be, produce, having,
# Nearest to s: tributary, isbn, infusion, gonna, whose, bobby, koalas, although,
# Nearest to and: or, but, while, including, which, bauds, however, slava,
# Nearest to at: during, near, on, under, discrediting, after, within, without,
# Nearest to can: could, may, would, will, must, should, might, cannot,
# Nearest to UNK: rectum, http, magdalene, gen, morris, ibook, sculptor, heretofore,
# Nearest to in: during, within, throughout, under, until, around, dominic, with,
# Nearest to such: well, known, these, classified, follows, dangerous, unsuitable, listed,
# Nearest to as: housewives, ugle, millisecond, uptown, kuleshov, untersuchungen, smack, fux,
# Nearest to often: sometimes, usually, commonly, generally, frequently, now, widely, also,
# Nearest to there: they, it, we, he, still, now, she, migrations,
# Nearest to all: both, every, many, several, each, any, those, some,
# Average loss at step 92000: 3.398392
# Average loss at step 94000: 3.250390
# Average loss at step 96000: 3.357270
# Average loss at step 98000: 3.237904
# Average loss at step 100000: 3.356699
# Nearest to not: never, still, equally, normally, now, almost, actually, t,
# Nearest to to: should, would, must, will, can, could, mno, inheritors,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to this: which, it, another, some, the, what, he, apo,
# Nearest to have: had, has, require, are, were, be, contain, having,
# Nearest to s: whose, his, pooh, isbn, nsc, specialised, seasoned, thereabouts,
# Nearest to and: or, but, while, however, when, including, although, like,
# Nearest to at: during, near, within, on, in, after, impeded, connecting,
# Nearest to can: could, may, must, would, will, should, cannot, might,
# Nearest to UNK: immigrate, malinowski, adr, controversially, succeeds, aaron, postel, malignant,
# Nearest to in: during, within, throughout, until, at, from, on, among,
# Nearest to such: well, known, these, follows, classified, serves, many, those,
# Nearest to as: ugle, kuleshov, millisecond, lipschitz, orators, undocumented, renounced, housewives,
# Nearest to often: sometimes, usually, commonly, generally, frequently, widely, still, now,
# Nearest to there: they, he, it, we, now, still, she, usually,
# Nearest to all: every, both, several, many, these, specimens, those, each,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
#Problem An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). 
#In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all 
#the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
print('data:', [reverse_dictionary[di] for di in data[:16]])
for bag_window in [1, 2, 4]:
    data_index = 0
    batch, labels = generate_cbow_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']
#
# with bag_window = 4:
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working']]
#     labels: ['term', 'of', 'abuse', 'first']

# %%
# CBOW model

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
bag_window = 2  # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64  # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                                   train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     490                 as_ref=input_arg.is_ref,
# --> 491                 preferred_dtype=default_dtype)
#     492           except TypeError as err:
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype)
#     701         if ret is None:
# --> 702           ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     703
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     574         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r"
# --> 575         % (dtype.name, t.dtype.name, str(t)))
#     576   return t
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float32: 'Tensor("sampled_softmax_loss/Reshape_1:0", shape=(?, 1, ?), dtype=float32)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-e3cd6e3c270f> in <module>()
#      34     loss = tf.reduce_mean(
#      35         tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
# ---> 36                                    train_labels, num_sampled, vocabulary_size))
#      37
#      38     # Optimizer.
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py in sampled_softmax_loss(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, remove_accidental_hits, partition_strategy, name)
#    1187       remove_accidental_hits=remove_accidental_hits,
#    1188       partition_strategy=partition_strategy,
# -> 1189       name=name)
#    1190   sampled_losses = nn_ops.softmax_cross_entropy_with_logits(labels=labels,
#    1191                                                             logits=logits)
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\ops\nn_impl.py in _compute_sampled_logits(weights, biases, labels, inputs, num_sampled, num_classes, num_true, sampled_values, subtract_log_q, remove_accidental_hits, partition_strategy, name)
#     970     row_wise_dots = math_ops.multiply(
#     971         array_ops.expand_dims(inputs, 1),
# --> 972         array_ops.reshape(true_w, new_true_w_shape))
#     973     # We want the row-wise dot plus biases which yields a
#     974     # [batch_size, num_true] tensor of true_logits.
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in multiply(x, y, name)
#     265
#     266 def multiply(x, y, name=None):
# --> 267   return gen_math_ops._mul(x, y, name)
#     268 multiply.__doc__ = gen_math_ops._mul.__doc__.replace("Mul", "`tf.multiply`")
#     269
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in _mul(x, y, name)
#    1623     A `Tensor`. Has the same type as `x`.
#    1624   """
# -> 1625   result = _op_def_lib.apply_op("Mul", x=x, y=y, name=name)
#    1626   return result
#    1627
#
# C:\Users\Vince\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py in apply_op(self, op_type_name, name, **keywords)
#     520                   "%s type %s of argument '%s'." %
#     521                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 522                    inferred_from[input_arg.type_attr]))
#     523
#     524           types = [values.dtype]
#
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type int32 of argument 'x'.
